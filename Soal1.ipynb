# %% [markdown]
# <a href="https://colab.research.google.com/github/ChokiaIsPuja/01-array/blob/main/Soal1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
24# Array kosong, akan diisi dengan input dari angka = int(input("Masukan Angka"))
arr = []

# Perulangan Pemngimputan Angka sebanyak 10
for i in range(10):
  angka = int(input("Masukan Angka  : "))
  arr.append(angka)

# Penampilan Data (Seluruh Array)
print("Array:", arr)

# Penampilan Data (Nilai Tertinggi)
print("Nilai Tertinggi:", max(arr))

#Penampilan Data (Nilai Terkecil)
print("Nilai Terkecil:", min(arr))

#Penampilan Data (Nilai Rata-rata)
print("Rata-rata:", sum(arr)/len(arr))
# Out:
# Masukan Angka  : 14
# Masukan Angka  : 52
# Masukan Angka  : 44
# Masukan Angka  : 32
# Masukan Angka  : 64
# Masukan Angka  : 82
# Masukan Angka  : 67
# Masukan Angka  : 55
# Masukan Angka  : 79
# Masukan Angka  : 44
# Array: [14, 52, 44, 32, 64, 82, 67, 55, 79, 44]
# Nilai Tertinggi: 82
# Nilai Terkecil: 14
# Rata-rata: 53.3

# %%
def insert_tengah(arr, posisi, nilai):
    # tambah ruang di akhir
    arr.append(0)

    # geser ke kanan
    for i in range(len(arr) - 1, posisi, -1):
        arr[i] = arr[i - 1]

    # isi nilai baru
    arr[posisi] = nilai

insert_tengah(arr, 1, 10)
print("Array Setelah Insert Tengah")
print(arr)

def delete_tengah(arr, posisi):
    # geser ke kiri
    for i in range(posisi, len(arr) - 1):
        arr[i] = arr[i + 1]

    # potong elemen terakhir
    arr[:] = arr[:-1]

delete_tengah(arr, 1)
print("Array Setelah Delete Tengah")
print(arr)
# Out:
# Array Setelah Insert Tengah
# [14, 10, 52, 44, 32, 64, 82, 67, 55, 79, 44]
# Array Setelah Delete Tengah
# [14, 52, 44, 32, 64, 82, 67, 55, 79, 44]

# %%
#buat grafik batang menggunakan matplotlib
import matplotlib.pyplot as plt
plt.bar(range(len(arr)), arr)
plt.title("Grafik Array")
plt.xlabel("Indeks")
plt.ylabel("Nilai")
plt.show()
