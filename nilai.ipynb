# %% [markdown]
# <a href="https://colab.research.google.com/github/ChokiaIsPuja/01-array/blob/main/nilai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

nilai = []

# Input 10 nilai
for i in range(10):
  angka = int(input("Masukan Angka  : "))
  nilai.append(angka)
# Out:
# Masukan Angka  : 55
# Masukan Angka  : 73
# Masukan Angka  : 822
# Masukan Angka  : 66
# Masukan Angka  : 71
# Masukan Angka  : 66
# Masukan Angka  : 34
# Masukan Angka  : 66
# Masukan Angka  : 73
# Masukan Angka  : 72

# %%
# Nilai tertinggi & terendah
nilai_tertinggi = max(nilai)
nilai_terendah = min(nilai)

# %%
# Rata-rata
rata_rata = sum(nilai) / len(nilai)

# Jumlah lulus (>=60)
lulus = 0
for angka in nilai:
    if angka >= 60:
        lulus += 1

tidak_lulus = len(nilai) - lulus

# %%
# Output
print("\n--- HASIL ANALISIS ---")
print("Nilai tertinggi :", nilai_tertinggi)
print("Nilai terendah  :", nilai_terendah)
print("Rata-rata       :", rata_rata)
print("Jumlah lulus    :", lulus)
print("Jumlah tidak lulus :", tidak_lulus)

# Grafik nilai tertinggi & terendah
plt.bar(["Tertinggi", "Terendah"], [nilai_tertinggi, nilai_terendah])
plt.title("Perbandingan Nilai Tertinggi dan Terendah")
plt.ylabel("Nilai")
plt.show()

# Grafik kelulusan
plt.bar(["Lulus", "Tidak Lulus"], [lulus, tidak_lulus])
plt.title("Grafik Kelulusan Mahasiswa")
plt.ylabel("Jumlah Mahasiswa")
plt.show()
# Out:
# --- HASIL ANALISIS ---
# Nilai tertinggi : 822
# Nilai terendah  : 34
# Rata-rata       : 139.8
# Jumlah lulus    : 8
# Jumlah tidak lulus : 2
